# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
import cv2  # Install opencv-python
import numpy as np

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_Model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# %%
# CAMERA can be 0 or 1 based on the default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcam's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height,224-width) pixels
    image_resized = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Show the image in a window
    cv2.imshow("Webcam Image", image_resized)

    # Make the image a numpy array and reshape it to the model's input shape.
    image = np.asarray(image_resized, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image = (image / 127.5) - 1

    # Predict using the model
    prediction = model.predict(image)
    class_id = np.argmax(prediction)
    class_name = class_names[class_id]
    confidence_score = prediction[0][class_id]

    # Draw bounding box around the object
    cv2.rectangle(image_resized, (0, 0), (224, 224), (255, 0, 0), 2)

    # Display class name and confidence score
    cv2.putText(image_resized, f'{class_name}: {confidence_score:.2f}', (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # Show the image with bounding boxes in a window
    cv2.imshow("Webcam Image with Bounding Boxes", image_resized)

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

# Release the camera and close all OpenCV windows
camera.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 31ms/step
# ...
# ...
# 1/1 [==============================] - 0s 47ms/step

# %%
# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height,224-width) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Show the image in a window
    cv2.imshow("Webcam Image", image)

    # Make the image a numpy array and reshape it to the models input shape.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image = (image / 127.5) - 1

    # Predicts the model
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", str(np.round(confidence_score * 100))[:-2], "%")

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 29ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 22ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 28ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 24ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 24ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: recyclable
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 31ms/step
# Class: recyclable
# Confidence Score: 100 %
# ...
